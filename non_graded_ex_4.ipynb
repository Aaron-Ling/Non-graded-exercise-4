# %% [markdown]
# Write a simple program for a card Role-Playing Game. Try to use only the concepts you have learned so far in the lectures.
#
# REQUIREMENTS:
#
# 1. Following are the different cards, with their characteristics, available to the player
#
# Name: Diablo
# Health: 100
# Attack: 90
# Defense: 60
#
# Name: Medusa
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Jester
# Health: 120
# Attack: 60
# Defense: 90
#
# Name: Troll
# Health: 150
# Attack: 40
# Defense: 94
#
# Name: Specter
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# Name: Savage
# Health: 100
# Attack: 90
# Defense: 50
#
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
# Name: Wimp
# Health: 110
# Attack: 40
# Defense: 85
#
# Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 55
#
# 2. Store the above card details using a suitable data structure like list, tuple, dictionary, or any combination of these
# 3. From these cards, assign a random deck of 5 cards to both the player and the computer (opponent).
#     3.1. This should happen whenever a new game begins
# 4. Keep the game running for as long as there are cards in the player's deck or for as long as there are cards in the opponent's deck
#     4.1. Show all the cards that the player has in their deck
#     4.2. Assign a random card to the opponent, and show that to the player, along with the details of that card. Only the details of this random card must be shown.
#     4.3. Ask the player to pick a card from their own deck to fight the opponent's card.
#     4.4. If the attack value of the player's card is more than the health of opponent's card, then the player wins this round.
#     4.5. Otherwise, the player's card will fight with the opponent's card.
#         4.5.1. Calculate the damage the player's card does to the opponent's card. This calculation should take care of the fact that the opponent's card will first defend the attack using its 'Defense' value. And if there is no defense value, only then will the player's attack value will affect the opponent card's health.
#
#         e.g.,
#         Player card
#
#         Name: Wimp
#         Health: 110
#         Attack: 40
#         Defense: 85
#
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 55
#
#         If the Wimp attacks Sorcerer, first, it will only affect Sorcerer's 'Defense' value. Sorcerer's defense value will decrease by the the attack value of player's Wimp card. Therefore, after the attack, the defense value will change from 55 to 15, as 55 - 40 = 15. Therefore,
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 15
#
#         Now, if in the next round, Wimp attacks Sorcerer again, then Sorcerer's defense value will decrease to 0, but its health will also be affected. The health will be affected by 25 points, as 40 - 15 = 25. So, Sorcerer's health will now decrease from 100 to 75
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 75
#         Attack: 70
#         Defense: 0
#
#         Now, let's say in a later round, the player uses the Marauder card, which has an attack value of 85, and the computer is using Sorcerer, whose health value is 75.
#
#         In that case, Sorcerer will be defeated, as 85 > 75. When this happens, remove the Sorcerer card from the deck of the opponent.
#
#         Display properly all these changes to the player at every round, so that they know how their attacks affected the round and what they can do next.
#
#         DO NOT just show the card details. Write proper statements, describing the process, as you may have seen in the demonstration given by the teacher
#
#         4.5.2. After the user's turn, make sure all the card values adjusted accordingly, just as described above.
#         4.5.3. ONLY a card's 'Defense' and 'Health' value changes after an attack. And once the 'Health' value of a card reaches 0 or drops below it, that card MUST be removed from the deck.
#         4.5.4. After the player's turn, pause the second for some seconds, e.g., time.sleep(3) will pause the game for 3 seconds.
#     4.6. Display that now it's the opponent's turn.
#     4.7. Make sure there are cards available in opponent's deck. If there aren't, then the game ends and the player wins.
#     4.8. If there are still cards available in opponent's deck, draw a random card from the opponent's deck, and display its details to the player.
#     4.9. Then display the cards available in the player's deck.
#     4.10 Ask the user to pick one card from their own deck to fight the opponent's card.
#     4.11. REPEAT THE SAME LOGIC AS STATED FROM POINT 4.4 TO 4.5.3. But this time, from the perspective of the opponent.
#     4.12. After the opponent's turn is over, display that a new round will begin in some seconds.
# 5. If it's found that the opponent has no card in their deck, then display a message stating player is the winner, otherwise display that the opponent won.

# %%
import random
import time

# Define the card deck with all possible cards
card_deck = [
    {"name": "Diablo", "health": 100, "attack": 90, "defense": 60},
    {"name": "Medusa", "health": 100, "attack": 70, "defense": 70},
    {"name": "Jester", "health": 120, "attack": 60, "defense": 90},
    {"name": "Troll", "health": 150, "attack": 40, "defense": 94},
    {"name": "Spectre", "health": 100, "attack": 70, "defense": 70},
    {"name": "Mist", "health": 100, "attack": 75, "defense": 65},
    {"name": "Barbarian", "health": 100, "attack": 90, "defense": 50},
    {"name": "Raider", "health": 100, "attack": 85, "defense": 50},
    {"name": "Wimp", "health": 110, "attack": 40, "defense": 85},
    {"name": "Mage", "health": 100, "attack": 70, "defense": 55}
]

# Number of cards each player will receive
deck_size = 5

# Draw randomly `deck_size` number of cards from the deck for both players
player_deck = random.sample(card_deck, deck_size)
opponent_deck = random.sample(card_deck, deck_size)

def display_card(card):
    print(f"Name: {card['name']}, Health: {card['health']}, Attack: {card['attack']}, Defense: {card['defense']}")

def player_choose_card(player_deck):
    print("\nYour cards:")
    for idx, card in enumerate(player_deck, 1):
        print(f"{idx}. {card['name']} (Health: {card['health']}, Attack: {card['attack']}, Defense: {card['defense']})")
    
    choice = int(input("\nChoose a card to play (1-5): ")) - 1
    return player_deck[choice]

def calculate_damage(attacker, defender):
    if defender['defense'] > 0:
        if attacker['attack'] > defender['defense']:
            damage = attacker['attack'] - defender['defense']
            defender['defense'] = 0
            defender['health'] -= damage
        else:
            defender['defense'] -= attacker['attack']
    else:
        defender['health'] -= attacker['attack']
    return defender

def game(player_deck, opponent_deck):
    while player_deck and opponent_deck:
        # Player's turn
        print("\nYour turn!")
        time.sleep(2)

        opponent_card = random.choice(opponent_deck)
        print("Opponent plays:")
        display_card(opponent_card)

        player_card = player_choose_card(player_deck)
        print("\nYou chose:")
        display_card(player_card)

        # Player attacks
        opponent_card = calculate_damage(player_card, opponent_card)
        
        print(f"\nAfter your attack, opponent's {opponent_card['name']} has {opponent_card['health']} health and {opponent_card['defense']} defense left.")
        
        if opponent_card['health'] <= 0:
            print(f"Opponent's {opponent_card['name']} has been defeated!")
            opponent_deck.remove(opponent_card)
        
        time.sleep(3)

        if not opponent_deck:
            print("Opponent has no cards left. You win!")
            break

        # Opponent's turn
        print("\nOpponent's turn!")
        time.sleep(2)

        opponent_card = random.choice(opponent_deck)
        print("Opponent plays:")
        display_card(opponent_card)

        player_card = random.choice(player_deck)
        print("\nOpponent attacks your:")
        display_card(player_card)

        # Opponent attacks
        player_card = calculate_damage(opponent_card, player_card)
        
        print(f"\nAfter opponent's attack, your {player_card['name']} has {player_card['health']} health and {player_card['defense']} defense left.")
        
        if player_card['health'] <= 0:
            print(f"Your {player_card['name']} has been defeated!")
            player_deck.remove(player_card)
        
        time.sleep(3)

        if not player_deck:
            print("You have no cards left. Opponent wins!")
            break

# Start the game
game(player_deck, opponent_deck)
# Out:
# Your turn!
# Opponent plays:
# Name: Troll, Health: 150, Attack: 40, Defense: 94
#
# Your cards:
# 1. Mist (Health: 100, Attack: 75, Defense: 65)
# 2. Raider (Health: 100, Attack: 85, Defense: 50)
# 3. Medusa (Health: 100, Attack: 70, Defense: 70)
# 4. Diablo (Health: 100, Attack: 90, Defense: 60)
# 5. Troll (Health: 150, Attack: 40, Defense: 94)
#
# You chose:
# Name: Diablo, Health: 100, Attack: 90, Defense: 60
#
# After your attack, opponent's Troll has 150 health and 4 defense left.
#
# Opponent's turn!
# Opponent plays:
# Name: Spectre, Health: 100, Attack: 70, Defense: 70
#
# Opponent attacks your:
# Name: Mist, Health: 100, Attack: 75, Defense: 65
#
# After opponent's attack, your Mist has 95 health and 0 defense left.
#
# Your turn!
# Opponent plays:
# Name: Mist, Health: 95, Attack: 75, Defense: 0
#
# Your cards:
# 1. Mist (Health: 95, Attack: 75, Defense: 0)
# 2. Raider (Health: 100, Attack: 85, Defense: 50)
# 3. Medusa (Health: 100, Attack: 70, Defense: 70)
# 4. Diablo (Health: 100, Attack: 90, Defense: 60)
# 5. Troll (Health: 150, Attack: 40, Defense: 4)
#
# You chose:
# Name: Mist, Health: 95, Attack: 75, Defense: 0
#
# After your attack, opponent's Mist has 20 health and 0 defense left.
#
# Opponent's turn!
# Opponent plays:
# Name: Spectre, Health: 100, Attack: 70, Defense: 70
#
# Opponent attacks your:
# Name: Raider, Health: 100, Attack: 85, Defense: 50
#
# After opponent's attack, your Raider has 80 health and 0 defense left.
#
# Your turn!
# Opponent plays:
# Name: Troll, Health: 150, Attack: 40, Defense: 4
#
# Your cards:
# 1. Mist (Health: 20, Attack: 75, Defense: 0)
# 2. Raider (Health: 80, Attack: 85, Defense: 0)
# 3. Medusa (Health: 100, Attack: 70, Defense: 70)
# 4. Diablo (Health: 100, Attack: 90, Defense: 60)
# 5. Troll (Health: 150, Attack: 40, Defense: 4)
#
# You chose:
# Name: Mist, Health: 20, Attack: 75, Defense: 0
#
# After your attack, opponent's Troll has 79 health and 0 defense left.
#
# Opponent's turn!
# Opponent plays:
# Name: Diablo, Health: 100, Attack: 90, Defense: 60
#
# Opponent attacks your:
# Name: Diablo, Health: 100, Attack: 90, Defense: 60
#
# After opponent's attack, your Diablo has 70 health and 0 defense left.
#
# Your turn!
# Opponent plays:
# Name: Troll, Health: 79, Attack: 40, Defense: 0
#
# Your cards:
# 1. Mist (Health: 20, Attack: 75, Defense: 0)
# 2. Raider (Health: 80, Attack: 85, Defense: 0)
# 3. Medusa (Health: 100, Attack: 70, Defense: 70)
# 4. Diablo (Health: 70, Attack: 90, Defense: 0)
# 5. Troll (Health: 79, Attack: 40, Defense: 0)
#
# You chose:
# Name: Mist, Health: 20, Attack: 75, Defense: 0
#
# After your attack, opponent's Troll has 4 health and 0 defense left.
#
# Opponent's turn!
# Opponent plays:
# Name: Mist, Health: 20, Attack: 75, Defense: 0
#
# Opponent attacks your:
# Name: Diablo, Health: 70, Attack: 90, Defense: 0
#
# After opponent's attack, your Diablo has -5 health and 0 defense left.
# Your Diablo has been defeated!
#
# Your turn!
# Opponent plays:
# Name: Troll, Health: 4, Attack: 40, Defense: 0
#
# Your cards:
# 1. Mist (Health: 20, Attack: 75, Defense: 0)
# 2. Raider (Health: 80, Attack: 85, Defense: 0)
# 3. Medusa (Health: 100, Attack: 70, Defense: 70)
# 4. Troll (Health: 4, Attack: 40, Defense: 0)
#
# You chose:
# Name: Medusa, Health: 100, Attack: 70, Defense: 70
#
# After your attack, opponent's Troll has -66 health and 0 defense left.
# Opponent's Troll has been defeated!
#
# Opponent's turn!
# Opponent plays:
# Name: Spectre, Health: 100, Attack: 70, Defense: 70
#
# Opponent attacks your:
# Name: Mist, Health: 20, Attack: 75, Defense: 0
#
# After opponent's attack, your Mist has -50 health and 0 defense left.
# Your Mist has been defeated!
#
# Your turn!
# Opponent plays:
# Name: Barbarian, Health: 100, Attack: 90, Defense: 50
#
# Your cards:
# 1. Raider (Health: 80, Attack: 85, Defense: 0)
# 2. Medusa (Health: 100, Attack: 70, Defense: 70)
# 3. Troll (Health: -66, Attack: 40, Defense: 0)
#
# You chose:
# Name: Medusa, Health: 100, Attack: 70, Defense: 70
#
# After your attack, opponent's Barbarian has 80 health and 0 defense left.
#
# Opponent's turn!
# Opponent plays:
# Name: Barbarian, Health: 80, Attack: 90, Defense: 0
#
# Opponent attacks your:
# Name: Troll, Health: -66, Attack: 40, Defense: 0
#
# After opponent's attack, your Troll has -156 health and 0 defense left.
# Your Troll has been defeated!
#
# Your turn!
# Opponent plays:
# Name: Barbarian, Health: 80, Attack: 90, Defense: 0
#
# Your cards:
# 1. Raider (Health: 80, Attack: 85, Defense: 0)
# 2. Medusa (Health: 100, Attack: 70, Defense: 70)
#
# You chose:
# Name: Medusa, Health: 100, Attack: 70, Defense: 70
#
# After your attack, opponent's Barbarian has 10 health and 0 defense left.
#
# Opponent's turn!
# Opponent plays:
# Name: Spectre, Health: 100, Attack: 70, Defense: 70
#
# Opponent attacks your:
# Name: Medusa, Health: 100, Attack: 70, Defense: 70
#
# After opponent's attack, your Medusa has 100 health and 0 defense left.
#
# Your turn!
# Opponent plays:
# Name: Barbarian, Health: 10, Attack: 90, Defense: 0
#
# Your cards:
# 1. Raider (Health: 80, Attack: 85, Defense: 0)
# 2. Medusa (Health: 100, Attack: 70, Defense: 0)
#
# You chose:
# Name: Raider, Health: 80, Attack: 85, Defense: 0
#
# After your attack, opponent's Barbarian has -75 health and 0 defense left.
# Opponent's Barbarian has been defeated!
#
# Opponent's turn!
# Opponent plays:
# Name: Diablo, Health: -5, Attack: 90, Defense: 0
#
# Opponent attacks your:
# Name: Medusa, Health: 100, Attack: 70, Defense: 0
#
# After opponent's attack, your Medusa has 10 health and 0 defense left.
#
# Your turn!
# Opponent plays:
# Name: Diablo, Health: -5, Attack: 90, Defense: 0
#
# Your cards:
# 1. Raider (Health: 80, Attack: 85, Defense: 0)
# 2. Medusa (Health: 10, Attack: 70, Defense: 0)
#
# You chose:
# Name: Raider, Health: 80, Attack: 85, Defense: 0
#
# After your attack, opponent's Diablo has -90 health and 0 defense left.
# Opponent's Diablo has been defeated!
#
# Opponent's turn!
# Opponent plays:
# Name: Spectre, Health: 100, Attack: 70, Defense: 70
#
# Opponent attacks your:
# Name: Medusa, Health: 10, Attack: 70, Defense: 0
#
# After opponent's attack, your Medusa has -60 health and 0 defense left.
# Your Medusa has been defeated!
#
# Your turn!
# Opponent plays:
# Name: Mist, Health: -50, Attack: 75, Defense: 0
#
# Your cards:
# 1. Raider (Health: 80, Attack: 85, Defense: 0)
#
# You chose:
# Name: Raider, Health: 80, Attack: 85, Defense: 0
#
# After your attack, opponent's Mist has -135 health and 0 defense left.
# Opponent's Mist has been defeated!
#
# Opponent's turn!
# Opponent plays:
# Name: Spectre, Health: 100, Attack: 70, Defense: 70
#
# Opponent attacks your:
# Name: Raider, Health: 80, Attack: 85, Defense: 0
#
# After opponent's attack, your Raider has 10 health and 0 defense left.
#
# Your turn!
# Opponent plays:
# Name: Spectre, Health: 100, Attack: 70, Defense: 70
#
# Your cards:
# 1. Raider (Health: 10, Attack: 85, Defense: 0)
#
# You chose:
# Name: Raider, Health: 10, Attack: 85, Defense: 0
#
# After your attack, opponent's Spectre has 85 health and 0 defense left.
#
# Opponent's turn!
# Opponent plays:
# Name: Spectre, Health: 85, Attack: 70, Defense: 0
#
# Opponent attacks your:
# Name: Raider, Health: 10, Attack: 85, Defense: 0
#
# After opponent's attack, your Raider has -60 health and 0 defense left.
# Your Raider has been defeated!
# You have no cards left. Opponent wins!
